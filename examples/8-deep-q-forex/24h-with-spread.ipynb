# %%
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
import glob
import os
import time
import joblib
from statistics import median
from rsi import apply as rsi

import pyfinancialdata
import trade_functions

from envs import SimpleTradingEnvironment
from agent import DQNAgent
from utils import get_scaler

# Auto reload
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
price_data = pyfinancialdata.get_multi_year(
    provider='oanda',
    instrument='EUR_USD',
    years=[2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
    time_group='24h',
    price_calculation='close',
    drop_non_price_columns=True,
)

# %%
# Add column for RSI to use as a feature for learning
price_data['rsi'] = rsi(price_data['price'])
environment_columns = ['rsi', 'price']

# Drop NA columns and reset index
price_data.dropna(inplace=True)

# %%
price_data['price'].plot(figsize=(16,6))

# %%
train_size = round(len(price_data)/3*2)
train_data = price_data[:train_size].copy()
train_data.reset_index(inplace=True)
test_data = price_data[train_size:].copy()
test_data.reset_index(inplace=True)
print('train size {0}, test size {1}'.format(len(train_data), len(test_data)))
# Out:
# train size 2539, test size 1270

# %%
episode=1000
batch_size=10

# %%
train_data.head(5)
# Out:
#         date   price        rsi
# 0 2006-01-17  1.2108  61.654089
# 1 2006-01-18  1.2107  61.523267
# 2 2006-01-19  1.2090  59.233980
# 3 2006-01-20  1.2134  63.047068
# 4 2006-01-22  1.2167  65.630385

# %%
env = SimpleTradingEnvironment(
    price_data=train_data,
    environment_columns=environment_columns,
    debug=False,
    spread=0.00015
)
state_size = env.observation_space.shape
action_size = env.action_space.n
scaler = get_scaler(env)
agent = DQNAgent(state_size, action_size)
train_results = pd.DataFrame()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train

# %%
for e in range(episode):
    state = env.reset()
    state = scaler.transform([state])
    for i in range(env.n_step):
        action = agent.act(state)
        next_state, reward, done = env.step(action)
        next_state = scaler.transform([next_state])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        if done:
            print(".", end='')
            if (e + 1) % 20 == 0:
                print("")
                print("episode: {0}/{1}".format(e + 1, episode))
                print("median profit: {0} pips, median trade count: {1}".format(
                    round(median(train_results['account_balance'].tolist()) / 0.0001),
                    round(median(train_results['trade_count'].tolist()))
                    )
                )
            train_results = train_results.append(env._stats(), ignore_index=True)
            break
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ....................
# episode: 20/1000
# median profit: -965 pips, median trade count: 126
# ....................
# episode: 40/1000
# median profit: 780 pips, median trade count: 166
# ....................
# episode: 60/1000
# median profit: 870 pips, median trade count: 186
# ....................
# episode: 80/1000
# median profit: 1889 pips, median trade count: 205
# ....................
# episode: 100/1000
# median profit: 2081 pips, median trade count: 212
# ....................
# episode: 120/1000
# median profit: 2354 pips, median trade count: 209
# ....................
# episode: 140/1000
# median profit: 2459 pips, median trade count: 209
# ....................
# episode: 160/1000
# median profit: 2837 pips, median trade count: 209
# ....................
# episode: 180/1000
# median profit: 3394 pips, median trade count: 207
# ....................
# episode: 200/1000
# median profit: 3573 pips, median trade count: 207
# ....................
# episode: 220/1000
# median profit: 3901 pips, median trade count: 207
# ....................
# episode: 240/1000
# median profit: 4007 pips, median trade count: 207
# ....................
# episode: 260/1000
# median profit: 3975 pips, median trade count: 210
# ....................
# episode: 280/1000
# median profit: 4111 pips, median trade count: 210
# ....................
# episode: 300/1000
# median profit: 4433 pips, median trade count: 211
# ....................
# episode: 320/1000
# median profit: 4648 pips, median trade count: 209
# ....................
# episode: 340/1000
# median profit: 4737 pips, median trade count: 209
# ....................
# episode: 360/1000
# median profit: 5186 pips, median trade count: 209
# ....................
# episode: 380/1000
# median profit: 5220 pips, median trade count: 210
# ....................
# episode: 400/1000
# median profit: 5472 pips, median trade count: 211
# ....................
# episode: 420/1000
# median profit: 5645 pips, median trade count: 210
# ....................
# episode: 440/1000
# median profit: 5688 pips, median trade count: 208
# ....................
# episode: 460/1000
# median profit: 5761 pips, median trade count: 208
# ....................
# episode: 480/1000
# median profit: 5951 pips, median trade count: 210
# ....................
# episode: 500/1000
# median profit: 6126 pips, median trade count: 211
# ....................
# episode: 520/1000
# median profit: 6178 pips, median trade count: 209
# ....................
# episode: 540/1000
# median profit: 6208 pips, median trade count: 207
# ....................
# episode: 560/1000
# median profit: 6208 pips, median trade count: 207
# ....................
# episode: 580/1000
# median profit: 6311 pips, median trade count: 203
# ....................
# episode: 600/1000
# median profit: 6359 pips, median trade count: 202
# ....................
# episode: 620/1000
# median profit: 6397 pips, median trade count: 201
# ....................
# episode: 640/1000
# median profit: 6460 pips, median trade count: 201
# ....................
# episode: 660/1000
# median profit: 6507 pips, median trade count: 199
# ....................
# episode: 680/1000
# median profit: 6614 pips, median trade count: 201
# ....................
# episode: 700/1000
# median profit: 6737 pips, median trade count: 201
# ....................
# episode: 720/1000
# median profit: 6737 pips, median trade count: 199
# ....................
# episode: 740/1000
# median profit: 6811 pips, median trade count: 200
# ....................
# episode: 760/1000
# median profit: 6825 pips, median trade count: 201
# ....................
# episode: 780/1000
# median profit: 6840 pips, median trade count: 199
# ....................
# episode: 800/1000
# median profit: 6864 pips, median trade count: 197
# ....................
# episode: 820/1000
# median profit: 6909 pips, median trade count: 196
# ....................
# episode: 840/1000
# median profit: 6919 pips, median trade count: 196
# ....................
# episode: 860/1000
# median profit: 6928 pips, median trade count: 195
# ....................
# episode: 880/1000
# median profit: 6928 pips, median trade count: 194
# ....................
# episode: 900/1000
# median profit: 6971 pips, median trade count: 195
# ....................
# episode: 920/1000
# median profit: 7004 pips, median trade count: 196
# ....................
# episode: 940/1000
# median profit: 7006 pips, median trade count: 194
# ....................
# episode: 960/1000
# median profit: 7004 pips, median trade count: 195
# ....................
# episode: 980/1000
# median profit: 6981 pips, median trade count: 196
# ....................
# episode: 1000/1000
# median profit: 7002 pips, median trade count: 196

# %%
train_results['profit_pips'] = train_results['account_balance'] / 0.0001
columns_to_plot = ['win_loss_ratio', 'profit_pips', 'trade_count']
fig, axes = plt.subplots(nrows=1,ncols=len(columns_to_plot), figsize=(16,6))
for i in range(len(columns_to_plot)):
    axes[i].title.set_text(columns_to_plot[i])
    train_results[columns_to_plot[i]].plot(ax=axes[i], subplots=True)
plt.show()

# %%
joblib.dump(agent, 'trained-model-24h-spread.pkl')
# Out:
# ['trained-model-24h-spread.pkl']

# %% [markdown]
# ## Test

# %%
# Uncomment to load agent from file 
# agent = joblib.load('trained-model-24h-spread.pkl')

# %%
# remake the env with test data
env = SimpleTradingEnvironment(
    price_data=test_data,
    environment_columns=environment_columns,
    spread=0.00015
)
state_size = env.observation_space.shape
action_size = env.action_space.n
scaler = get_scaler(env)
test_results = pd.DataFrame()

# %%
for e in range(1000):
    state = env.reset()
    state = scaler.transform([state])
    for i in range(env.n_step):
        action = agent.act(state)
        next_state, reward, done = env.step(action)
        next_state = scaler.transform([next_state])
        state = next_state
        if done:
            test_results = test_results.append(env._stats(), ignore_index=True)
            break

# %%
test_results['account_balance_pips'] = test_results['account_balance'] / 0.0001
print('Median profit: {0} pips'.format(test_results['account_balance_pips'].median()))
# Out:
# Median profit: 1959.6749999998874 pips

# %%
plt.figure(figsize=(16,6))
test_results.hist(column='account_balance_pips', bins=60)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x134fed510>]],
#       dtype=object)

# %% [markdown]
# ## Analyse positions on test data

# %%
# remake the env with test data
env = SimpleTradingEnvironment(
    price_data=test_data.copy(),
    environment_columns=environment_columns,
    save_positions_on_df=True,
    spread=0.00015
)
state_size = env.observation_space.shape
action_size = env.action_space.n

# %%
state = env.reset()
state = scaler.transform([state])
for i in range(env.n_step):
    action = agent.act(state)
    next_state, reward, done = env.step(action)
    next_state = scaler.transform([next_state])
    state = next_state
    if done:
        break

# %%
env._stats()
# Out:
# {'trade_count': 283,
#  'win_loss_ratio': 0.5512367491166078,
#  'account_balance': 0.31872499999998727,
#  'unrealised_pl': 0}

# %%
position_data = env.price_data.copy()

# %%
position_data['position'] = position_data['position'] - 1

# %%
trades = trade_functions.create_trades_from_positions(position_data.copy())

# %%
trade_functions.show_positions_on_price_plot(position_data.copy())
# Out:
# 284 positions to plot...

# %%
trade_functions.get_trade_statistics(trades.copy())
# Out:
# Profitable: 55.28%
# Ratio of long to short positions: 8.43
# Median profit: 0.0
# Total profit: 0.33995000000000064
# Median position length: 1.0
# Number of trades: 284

# %%
trades
# Out:
#     enter_date  enter_price  exit_date  exit_price  position_length  position  \
# 0   2013-12-04      1.35852 2013-12-05     1.36690                1       NaN
# 1   2013-12-05      1.36690 2014-01-27     1.36742               45      -1.0
# 2   2014-01-27      1.36742 2014-01-28     1.36542                1       1.0
# 3   2014-01-28      1.36542 2014-01-31     1.34854                3      -1.0
# 4   2014-01-31      1.34854 2014-02-02     1.34876                1       1.0
# ..         ...          ...        ...         ...              ...       ...
# 279 2017-12-18      1.17839 2017-12-19     1.18374                1       1.0
# 280 2017-12-20      1.18774 2017-12-21     1.18524                1       1.0
# 281 2017-12-22      1.18617 2017-12-25     1.18711                1       1.0
# 282 2017-12-26      1.18574 2017-12-27     1.19004                1       1.0
# 283 2017-12-28      1.19396 2017-12-29     1.20039                1       1.0
#
#       profit  profitable  account_balance
# 0        NaN       False              NaN
# 1   -0.00052       False         -0.00052
# 2   -0.00200       False         -0.00252
# 3    0.01688        True          0.01436
# 4    0.00022        True          0.01458
# ..       ...         ...              ...
# 279  0.00535        True          0.33078
# 280 -0.00250       False          0.32828
# 281  0.00094        True          0.32922
# 282  0.00430        True          0.33352
# 283  0.00643        True          0.33995
#
# [284 rows x 9 columns]

# %%
# Plot account balance
trades['account_balance'].plot(figsize=(16,6))

# %% [markdown]
# ## Show distribution of maximum drawdown

# %%
max_drawdown_results = trade_functions.plot_max_drawdown_distribution(trades.copy())
plt.figure(figsize=(16,6))
plt.hist(max_drawdown_results, bins=100);
# Out:
# Median drawdown: -0.07367999999999963
