# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import pyfinancialdata
import pandas_techinal_indicators as ta
from sklearn.ensemble import RandomForestClassifier

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Training data

# %%
train_data = pyfinancialdata.get_multi_year(
    provider='histdata',
    instrument='SPXUSD',
    years=[2010, 2011, 2012, 2013, 2014, 2015, 2016],
    time_group='12h',
    price_calculation='close',
    drop_non_price_columns=False,
)

# %%
train_data['price'].plot(figsize=(16,6))

# %%
# Remove datetime index
train_data.reset_index(inplace=True)
# Add column for the direction of the next bar
train_data['next_direction'] = np.where(train_data.shift(-1)['price'] > train_data['price'], 1, -1)

# %%
# Add features to help predict next_direction
def add_features(data):
    for x in [5, 14, 26, 44, 66]:
        data = ta.relative_strength_index(data, n=x)
        data = ta.stochastic_oscillator_d(data, n=x)
        data = ta.average_true_range(data, n=x)
        data = ta.momentum(data, n=x)
        data = ta.rate_of_change(data, n=x)
        data = ta.commodity_channel_index(data, n=x)
        data = ta.trix(data, n=x)
        data = ta.vortex_indicator(data, n=x)
    
    data['ema50'] = data['close'] / data['close'].ewm(50).mean()
    data['ema21'] = data['close'] / data['close'].ewm(21).mean()
    data['ema14'] = data['close'] / data['close'].ewm(14).mean()
    data['ema5'] = data['close'] / data['close'].ewm(5).mean()
        
    data = ta.macd(data, n_fast=12, n_slow=26)

    return data

# %%
# Add features
train_data = add_features(train_data.copy())
# Remove NA rows
train_data = train_data.replace([np.inf, -np.inf], np.nan)
train_data = train_data.dropna()

# %%
train_data.tail(5)
# Out:
#                     date    close     high      low     open    price  \
# 3480 2016-12-28 12:00:00  2246.75  2254.50  2243.50  2254.50  2246.75
# 3481 2016-12-29 00:00:00  2242.50  2249.75  2241.50  2247.00  2242.50
# 3482 2016-12-29 12:00:00  2249.50  2250.00  2239.50  2242.25  2249.50
# 3483 2016-12-30 00:00:00  2240.75  2252.50  2236.75  2249.75  2240.75
# 3484 2016-12-30 12:00:00  2233.50  2241.00  2228.00  2241.00  2233.50
#
#       next_direction     RSI_5    SO%d_5      ATR_5  ...    CCI_66   Trix_66  \
# 3480              -1  0.157950  0.307565   9.634188  ...  0.674567  0.000367
# 3481               1  0.135655  0.245448   9.172792  ...  0.539456  0.000372
# 3482              -1  0.111951  0.481092   9.615195  ...  0.570740  0.000376
# 3483              -1  0.082294  0.405384  11.660130  ...  0.452743  0.000380
# 3484              -1  0.036343  0.411282  12.106753  ...  0.133866  0.000384
#
#       Vortex_66     ema50     ema21     ema14      ema5  MACD_12_26  \
# 3480   0.226027  1.016533  1.001976  0.997899  0.995396    4.057490
# 3481   0.214889  1.014320  1.000077  0.996276  0.994588    2.582469
# 3482   0.218224  1.017137  1.003053  0.999427  0.998077    1.955801
# 3483   0.203654  1.012919  0.999190  0.995835  0.995157    0.744527
# 3484   0.155698  1.009451  0.996140  0.993102  0.993272   -0.791309
#
#       MACDsign_12_26  MACDdiff_12_26
# 3480        6.933680       -2.876190
# 3481        6.063438       -3.480969
# 3482        5.241910       -3.286110
# 3483        4.342434       -3.597907
# 3484        3.315685       -4.106994
#
# [5 rows x 54 columns]

# %%
# The features are all columns except 
features = [column for column in train_data.columns if column not in ['next_direction', 'date']]
X_train = train_data[features]
y_train = train_data['next_direction']

# %% [markdown]
# ## The model

# %%
model = RandomForestClassifier(n_jobs=-1, n_estimators=65)
# Fit the model
model.fit(X_train, y_train.values.ravel());

# %% [markdown]
# ## Test data

# %%
test_data = pyfinancialdata.get_multi_year(
    provider='histdata',
    instrument='SPXUSD',
    years=[2017],
    time_group='12h',
    price_calculation='close',
    drop_non_price_columns=False,
)

# %%
test_data['price'].plot(figsize=(16,6))

# %% [markdown]
# ## Test the model

# %%
# Remove datetime index
test_data.reset_index(inplace=True)
# Add features
test_data = add_features(test_data.copy())
# Remove NA rows
test_data = test_data.replace([np.inf, -np.inf], np.nan)
test_data = test_data.dropna()
# Make a new blank columns for predictions
test_data['next_prediction'] = np.NaN
# Reset index
test_data.reset_index(inplace=True)

# %%
# Add a prediction for each row
for i in range(len(test_data)):
    test_data.at[i, 'next_prediction'] = model.predict(test_data[features].iloc[[i]])

# %%
test_data['next_prediction'].value_counts()
# Out:
# -1.0    323
#  1.0     36
# Name: next_prediction, dtype: int64

# %%
# add columns for price direction and predicted direction
test_data['next_direction'] = np.where(test_data['price'] > test_data['price'].shift(-1), -1, 1)
test_data['correct'] = test_data['next_prediction'] == test_data['next_direction']

# %%
# How often does the model predict the correct price change direction
test_data['correct'].value_counts()
# Out:
# False    204
# True     155
# Name: correct, dtype: int64

# %% [markdown]
# ## Trade results

# %%
# Create trades from predictions
positions = pd.DataFrame()
positions['price'] = test_data['price']
positions['high'] = test_data['high']
positions['low'] = test_data['low']
positions['date'] = test_data['date']
positions['position'] = test_data['next_direction']
positions['position_group'] = (positions['position'].diff(1) != 0).astype('int').cumsum()
positions['position_group_shifted'] = positions['position_group'].shift(1)

# %%
trades = pd.DataFrame({
        'enter_date': positions.reset_index().groupby('position_group').date.first(),
        'enter_price': positions.reset_index().groupby('position_group')['price'].first(),
        'exit_date': positions.reset_index().groupby('position_group_shifted').date.last(),
        'exit_price': positions.reset_index().groupby('position_group_shifted')['price'].last(),
        'position_length': positions.groupby('position_group').size(),
        'position': positions.groupby('position_group')['position'].first(),
    }).reset_index(drop=True)

trades['profit'] = ((trades['exit_price'] - trades['enter_price']) * trades['position'])
trades['profitable'] = trades['profit'] > 0

# %%
print('{0} long positions, {1} short positions'.format(
    len(positions.loc[positions['position'] == 1]),
    len(positions.loc[positions['position'] == -1])
))
# Out:
# 218 long positions, 141 short positions

# %%
print('Profitability: {0}%'.format(
    round(len(trades.loc[trades['profitable'] == True]) / len(trades) * 100)
))
# Out:
# Profitability: 98%
