# %%
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
import glob
import os
import time
import joblib
from statistics import median

import pyfinancialdata
import trade_functions
import pandas_techinal_indicators

from envs import SimpleTradingEnvironment
from agent import DQNAgent
from utils import get_scaler

# Auto reload
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
# %%javascript
# var nb = IPython.notebook;
# var kernel = IPython.notebook.kernel;
# var command = "NOTEBOOK_FULL_PATH = '" + nb.base_url + nb.notebook_path + "'";
# kernel.execute(command);

# %%
# A variable for the name of this notebook
notebook_name = os.path.splitext(os.path.basename(NOTEBOOK_FULL_PATH))[0]

# %%
price_data = pyfinancialdata.get_multi_year(
    provider='oanda',
    instrument='EUR_USD',
    years=range(2006, 2021),
    time_group='6h',
    price_calculation='close',
)

# %%
environment_columns = ['price', 'RSI_14', 'ATR_7', 'ADX_7_14']

def add_features(df):
    '''
    Adds feature columns to a pandas price data df
    '''
    df.reset_index(inplace=True)
    
    df = pandas_techinal_indicators.relative_strength_index(df, 14)
    df = pandas_techinal_indicators.average_true_range(df, 7)
    df = pandas_techinal_indicators.average_directional_movement_index(df, 7, 14)
    
    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    return df

# %%
price_data = add_features(price_data.copy())

# %%
price_data['price'].plot(figsize=(16,6))

# %%
train_size = round(len(price_data)/3*2)
train_data = price_data[:train_size].copy()
train_data.reset_index(inplace=True)
test_data = price_data[train_size:].copy()
test_data.reset_index(inplace=True)
print('train size {0}, test size {1}'.format(len(train_data), len(test_data)))
# Out:
# train size 10703, test size 5352

# %%
episode=1000
batch_size=10

# %%
train_data.head(5)
# Out:
#    index                date    close     high      low     open    price  \
# 0      0 2006-01-06 12:00:00  1.21538  1.21808  1.20880  1.20938  1.21538
# 1      1 2006-01-06 18:00:00  1.21520  1.21638  1.21458  1.21538  1.21520
# 2      2 2006-01-08 18:00:00  1.21420  1.21540  1.21360  1.21540  1.21420
# 3      3 2006-01-09 00:00:00  1.21460  1.21550  1.21290  1.21410  1.21460
# 4      4 2006-01-09 06:00:00  1.20752  1.21480  1.20648  1.21460  1.20752
#
#      RSI_14     ATR_7  ADX_7_14
# 0  0.838629  0.005064  0.537637
# 1  0.838629  0.004246  0.530643
# 2  0.781232  0.003633  0.499229
# 3  0.739518  0.003375  0.492555
# 4  0.472519  0.004612  0.496234

# %%
env = SimpleTradingEnvironment(
    price_data=train_data,
    environment_columns=environment_columns,
    debug=False,
    spread=0.00015
)
state_size = env.observation_space.shape
action_size = env.action_space.n
scaler = get_scaler(env)
agent = DQNAgent(state_size, action_size)
train_results = pd.DataFrame()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                224
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 1,379
# Trainable params: 1,379
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train

# %%
for e in range(episode):
    state = env.reset()
    state = scaler.transform([state])
    for i in range(env.n_step):
        action = agent.act(state)
        next_state, reward, done = env.step(action)
        next_state = scaler.transform([next_state])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        if done:
            print(".", end='')
            if (e + 1) % 20 == 0:
                print("")
                print("episode: {0}/{1}".format(e + 1, episode))
                print("median profit: {0} pips, median trade count: {1}".format(
                    round(median(train_results['account_balance'].tolist()) / 0.0001),
                    round(median(train_results['trade_count'].tolist()))
                    )
                )
            train_results = train_results.append(env._stats(), ignore_index=True)
            break
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ....................
# episode: 20/1000
# median profit: -1531 pips, median trade count: 1008
# ....................
# episode: 40/1000
# median profit: -1531 pips, median trade count: 1003
# ....................
# episode: 60/1000
# median profit: -1079 pips, median trade count: 947
# ....................
# episode: 80/1000
# median profit: -1049 pips, median trade count: 902
# ....................
# episode: 100/1000
# median profit: -881 pips, median trade count: 828
# ....................
# episode: 120/1000
# median profit: -227 pips, median trade count: 762
# ....................
# episode: 140/1000
# median profit: 382 pips, median trade count: 717
# ....................
# episode: 160/1000
# median profit: 467 pips, median trade count: 697
# ....................
# episode: 180/1000
# median profit: 499 pips, median trade count: 688
# ....................
# episode: 200/1000
# median profit: 430 pips, median trade count: 680
# ....................
# episode: 220/1000
# median profit: 430 pips, median trade count: 689
# ....................
# episode: 240/1000
# median profit: 579 pips, median trade count: 700
# ....................
# episode: 260/1000
# median profit: 776 pips, median trade count: 689
# ....................
# episode: 280/1000
# median profit: 940 pips, median trade count: 691
# ....................
# episode: 300/1000
# median profit: 1221 pips, median trade count: 689
# ....................
# episode: 320/1000
# median profit: 1395 pips, median trade count: 689
# ....................
# episode: 340/1000
# median profit: 1093 pips, median trade count: 686
# ....................
# episode: 360/1000
# median profit: 1294 pips, median trade count: 686
# ....................
# episode: 380/1000
# median profit: 1146 pips, median trade count: 686
# ....................
# episode: 400/1000
# median profit: 1092 pips, median trade count: 680
# ....................
# episode: 420/1000
# median profit: 1093 pips, median trade count: 676
# ....................
# episode: 440/1000
# median profit: 1087 pips, median trade count: 674
# ....................
# episode: 460/1000
# median profit: 1146 pips, median trade count: 668
# ....................
# episode: 480/1000
# median profit: 1367 pips, median trade count: 667
# ....................
# episode: 500/1000
# median profit: 1421 pips, median trade count: 673
# ....................
# episode: 520/1000
# median profit: 1536 pips, median trade count: 668
# ....................
# episode: 540/1000
# median profit: 1596 pips, median trade count: 665
# ....................
# episode: 560/1000
# median profit: 1758 pips, median trade count: 663
# ....................
# episode: 580/1000
# median profit: 1771 pips, median trade count: 663
# ....................
# episode: 600/1000
# median profit: 1812 pips, median trade count: 659
# ....................
# episode: 620/1000
# median profit: 1840 pips, median trade count: 656
# ....................
# episode: 640/1000
# median profit: 1820 pips, median trade count: 656
# ....................
# episode: 660/1000
# median profit: 1769 pips, median trade count: 653
# ....................
# episode: 680/1000
# median profit: 1750 pips, median trade count: 651
# ....................
# episode: 700/1000
# median profit: 1664 pips, median trade count: 651
# ....................
# episode: 720/1000
# median profit: 1629 pips, median trade count: 647
# ....................
# episode: 740/1000
# median profit: 1608 pips, median trade count: 646
# ....................
# episode: 760/1000
# median profit: 1536 pips, median trade count: 644
# ....................
# episode: 780/1000
# median profit: 1608 pips, median trade count: 645
# ....................
# episode: 800/1000
# median profit: 1596 pips, median trade count: 646
# ....................
# episode: 820/1000
# median profit: 1538 pips, median trade count: 647
# ....................
# episode: 840/1000
# median profit: 1488 pips, median trade count: 651
# ....................
# episode: 860/1000
# median profit: 1512 pips, median trade count: 649
# ....................
# episode: 880/1000
# median profit: 1512 pips, median trade count: 647
# ....................
# episode: 900/1000
# median profit: 1478 pips, median trade count: 648
# ....................
# episode: 920/1000
# median profit: 1406 pips, median trade count: 649
# ....................
# episode: 940/1000
# median profit: 1345 pips, median trade count: 648
# ....................
# episode: 960/1000
# median profit: 1306 pips, median trade count: 649
# ....................
# episode: 980/1000
# median profit: 1207 pips, median trade count: 648
# ....................
# episode: 1000/1000
# median profit: 1194 pips, median trade count: 649

# %%
train_results['profit_pips'] = train_results['account_balance'] / 0.0001
columns_to_plot = ['win_loss_ratio', 'profit_pips', 'trade_count']
fig, axes = plt.subplots(nrows=1,ncols=len(columns_to_plot), figsize=(16,6))
for i in range(len(columns_to_plot)):
    axes[i].title.set_text(columns_to_plot[i])
    train_results[columns_to_plot[i]].plot(ax=axes[i], subplots=True)
plt.show()

# %%
joblib.dump(agent, '{0}.pkl'.format(notebook_name))
# Out:
# ['6h-EUR_USD.pkl']

# %% [markdown]
# ## Test

# %%
# Uncomment to load agent from file 
agent = joblib.load('{0}.pkl'.format(notebook_name))

# %%
# remake the env with test data
env = SimpleTradingEnvironment(
    price_data=test_data,
    environment_columns=environment_columns,
    spread=0.00015
)
state_size = env.observation_space.shape
action_size = env.action_space.n
scaler = get_scaler(env)
test_results = pd.DataFrame()

# %%
for e in range(1000):
    state = env.reset()
    state = scaler.transform([state])
    for i in range(env.n_step):
        action = agent.act(state)
        next_state, reward, done = env.step(action)
        next_state = scaler.transform([next_state])
        state = next_state
        if done:
            test_results = test_results.append(env._stats(), ignore_index=True)
            break

# %%
test_results['account_balance_pips'] = test_results['account_balance'] / 0.0001
test_results['account_drawdown_max_pips'] = test_results['account_drawdown_max'] / 0.0001
print('Median profit: {0} pips'.format(test_results['account_balance_pips'].median()))
print('Median win/loss ratio: {0}'.format(test_results['win_loss_ratio'].median()))
print('Median drawdown: {0} pips'.format(test_results['account_drawdown_max_pips'].median()))
print('Median trade count: {0}'.format(test_results['trade_count'].median()))
print('Trades per day: {0}'.format(test_results['trade_count'].median() / (test_data['date'].iloc[-1] - test_data['date'].iloc[0]).days))
# Out:
# Median profit: 3273.7249999998403 pips
# Median win/loss ratio: 0.7156353226161638
# Median drawdown: -1082.2750000000115 pips
# Median trade count: 262.0
# Trades per day: 0.14604236343366778

# %%
# Historgram of account balance
plt.figure(figsize=(16,6))
test_results.hist(column='account_balance_pips', bins=60)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12be64e90>]],
#       dtype=object)

# %%
# Historgram of max drawdown
plt.figure(figsize=(16,6))
test_results.hist(column='account_drawdown_max_pips', bins=60)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12d9cd7d0>]],
#       dtype=object)

# %% [markdown]
# ## Analyse positions on test data

# %%
# remake the env with test data
env = SimpleTradingEnvironment(
    price_data=test_data.copy(),
    environment_columns=environment_columns,
    save_positions_on_df=True,
    spread=0.00015
)
state_size = env.observation_space.shape
action_size = env.action_space.n

# %%
state = env.reset()
state = scaler.transform([state])
for i in range(env.n_step):
    action = agent.act(state)
    next_state, reward, done = env.step(action)
    next_state = scaler.transform([next_state])
    state = next_state
    if done:
        break

# %%
env._stats()
# Out:
# {'trade_count': 258,
#  'win_loss_ratio': 0.7131782945736435,
#  'account_balance': 0.3820499999999867,
#  'unrealised_pl': -0.03817500000000007,
#  'account_drawdown': 0.0,
#  'account_drawdown_max': -0.09255000000000058}

# %%
position_data = env.price_data.copy()

# %%
position_data['position'] = position_data['position'] - 1

# %%
trades = trade_functions.create_trades_from_positions(position_data.copy())

# %%
trade_functions.show_positions_on_price_plot(position_data.copy())
# Out:
# 260 positions to plot...

# %%
trade_functions.get_trade_statistics(trades.copy())
# Out:
# Profitable: 71.92%
# Ratio of long to short positions: 0.59
# Median profit: 0.0
# Total profit: 0.36329999999999885
# Median position length: 6.0
# Number of trades: 260

# %%
trades
# Out:
#              enter_date  enter_price           exit_date  exit_price  \
# 0   2015-06-15 12:00:00      1.12564 2015-06-15 18:00:00     1.12756
# 1   2015-06-15 18:00:00      1.12756 2015-06-16 06:00:00     1.12334
# 2   2015-06-16 12:00:00      1.12351 2015-06-23 12:00:00     1.11628
# 3   2015-06-28 18:00:00      1.09749 2015-07-07 12:00:00     1.09654
# 4   2015-07-07 12:00:00      1.09654 2015-07-08 00:00:00     1.10078
# ..                  ...          ...                 ...         ...
# 255 2020-03-05 18:00:00      1.12226 2020-03-06 12:00:00     1.13054
# 256 2020-03-06 12:00:00      1.13054 2020-03-11 18:00:00     1.12616
# 257 2020-03-11 18:00:00      1.12616 2020-03-12 06:00:00     1.12373
# 258 2020-03-12 06:00:00      1.12373 2020-03-12 12:00:00     1.11856
# 259 2020-03-12 12:00:00      1.11856 2020-05-14 06:00:00     1.08046
#
#      position_length  position   profit  profitable  account_balance
# 0                  1       NaN      NaN       False              NaN
# 1                  2      -1.0  0.00422        True          0.00422
# 2                 21      -1.0  0.00723        True          0.01145
# 3                 28      -1.0  0.00095        True          0.01240
# 4                  2       1.0  0.00424        True          0.01664
# ..               ...       ...      ...         ...              ...
# 255                3       1.0  0.00828        True          0.39428
# 256               14      -1.0  0.00438        True          0.39866
# 257                2       1.0 -0.00243       False          0.39623
# 258                1      -1.0  0.00517        True          0.40140
# 259              188       1.0 -0.03810       False          0.36330
#
# [260 rows x 9 columns]

# %%
# Plot account balance
trades['account_balance'].plot(figsize=(16,6))

# %% [markdown]
# ## Show distribution of maximum drawdown

# %%
max_drawdown_results = trade_functions.plot_max_drawdown_distribution(trades.copy())
plt.figure(figsize=(16,6))
plt.hist(max_drawdown_results, bins=100);
# Out:
# Median drawdown: -0.08154000000000006
