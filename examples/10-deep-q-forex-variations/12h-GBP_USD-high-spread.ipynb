# %%
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
import glob
import os
import time
import joblib
from statistics import median

import pyfinancialdata
import trade_functions
import pandas_techinal_indicators

from envs import SimpleTradingEnvironment
from agent import DQNAgent
from utils import get_scaler

# Auto reload
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
# %%javascript
# var nb = IPython.notebook;
# var kernel = IPython.notebook.kernel;
# var command = "NOTEBOOK_FULL_PATH = '" + nb.base_url + nb.notebook_path + "'";
# kernel.execute(command);

# %%
# A variable for the name of this notebook
notebook_name = os.path.splitext(os.path.basename(NOTEBOOK_FULL_PATH))[0]

# %%
price_data = pyfinancialdata.get_multi_year(
    provider='oanda',
    instrument='GBP_USD',
    years=range(2006, 2021),
    time_group='12h',
    price_calculation='close',
)

# %%
environment_columns = ['price', 'RSI_14', 'ATR_7', 'ADX_7_14']

def add_features(df):
    '''
    Adds feature columns to a pandas price data df
    '''
    df.reset_index(inplace=True)
    
    df = pandas_techinal_indicators.relative_strength_index(df, 14)
    df = pandas_techinal_indicators.average_true_range(df, 7)
    df = pandas_techinal_indicators.average_directional_movement_index(df, 7, 14)
    
    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    return df

# %%
price_data = add_features(price_data.copy())

# %%
price_data['price'].plot(figsize=(16,6))

# %%
train_size = round(len(price_data)/3*2)
train_data = price_data[:train_size].copy()
train_data.reset_index(inplace=True)
test_data = price_data[train_size:].copy()
test_data.reset_index(inplace=True)
print('train size {0}, test size {1}'.format(len(train_data), len(test_data)))
# Out:
# train size 5562, test size 2781

# %%
episode=1000
batch_size=10

# %%
train_data.head(5)
# Out:
#    index                date    close     high      low     open    price  \
# 0      0 2006-01-12 12:00:00  1.76080  1.77135  1.75800  1.76825  1.76080
# 1      1 2006-01-13 00:00:00  1.76665  1.77165  1.75960  1.76080  1.76665
# 2      2 2006-01-13 12:00:00  1.77740  1.77845  1.76485  1.76665  1.77740
# 3      3 2006-01-15 12:00:00  1.77780  1.77900  1.77460  1.77460  1.77780
# 4      4 2006-01-16 00:00:00  1.76935  1.77970  1.76885  1.77780  1.76935
#
#      RSI_14     ATR_7  ADX_7_14
# 0  0.494794  0.010280  0.317634
# 1  0.500048  0.010723  0.307017
# 2  0.606954  0.011444  0.302499
# 3  0.614644  0.009680  0.283419
# 4  0.497277  0.009973  0.299910

# %%
env = SimpleTradingEnvironment(
    price_data=train_data,
    environment_columns=environment_columns,
    debug=False,
    spread=0.0007
)
state_size = env.observation_space.shape
action_size = env.action_space.n
scaler = get_scaler(env)
agent = DQNAgent(state_size, action_size)
train_results = pd.DataFrame()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                224
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 1,379
# Trainable params: 1,379
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train

# %%
for e in range(episode):
    state = env.reset()
    state = scaler.transform([state])
    for i in range(env.n_step):
        action = agent.act(state)
        next_state, reward, done = env.step(action)
        next_state = scaler.transform([next_state])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        if done:
            print(".", end='')
            if (e + 1) % 20 == 0:
                print("")
                print("episode: {0}/{1}".format(e + 1, episode))
                print("median profit: {0} pips, median trade count: {1}".format(
                    round(median(train_results['account_balance'].tolist()) / 0.0001),
                    round(median(train_results['trade_count'].tolist()))
                    )
                )
            train_results = train_results.append(env._stats(), ignore_index=True)
            break
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ....................
# episode: 20/1000
# median profit: 1702 pips, median trade count: 335
# ....................
# episode: 40/1000
# median profit: 2303 pips, median trade count: 404
# ....................
# episode: 60/1000
# median profit: 3881 pips, median trade count: 404
# ....................
# episode: 80/1000
# median profit: 3724 pips, median trade count: 433
# ....................
# episode: 100/1000
# median profit: 4526 pips, median trade count: 472
# ....................
# episode: 120/1000
# median profit: 5516 pips, median trade count: 485
# ....................
# episode: 140/1000
# median profit: 6122 pips, median trade count: 490
# ....................
# episode: 160/1000
# median profit: 6309 pips, median trade count: 491
# ....................
# episode: 180/1000
# median profit: 6679 pips, median trade count: 490
# ....................
# episode: 200/1000
# median profit: 6679 pips, median trade count: 472
# ....................
# episode: 220/1000
# median profit: 7019 pips, median trade count: 456
# ....................
# episode: 240/1000
# median profit: 7112 pips, median trade count: 446
# ....................
# episode: 260/1000
# median profit: 7257 pips, median trade count: 444
# ....................
# episode: 280/1000
# median profit: 7282 pips, median trade count: 445
# ....................
# episode: 300/1000
# median profit: 7231 pips, median trade count: 444
# ....................
# episode: 320/1000
# median profit: 7019 pips, median trade count: 440
# ....................
# episode: 340/1000
# median profit: 6915 pips, median trade count: 439
# ....................
# episode: 360/1000
# median profit: 7002 pips, median trade count: 437
# ....................
# episode: 380/1000
# median profit: 6832 pips, median trade count: 437
# ....................
# episode: 400/1000
# median profit: 6688 pips, median trade count: 439
# ....................
# episode: 420/1000
# median profit: 6679 pips, median trade count: 439
# ....................
# episode: 440/1000
# median profit: 6625 pips, median trade count: 440
# ....................
# episode: 460/1000
# median profit: 7002 pips, median trade count: 446
# ....................
# episode: 480/1000
# median profit: 7019 pips, median trade count: 446
# ....................
# episode: 500/1000
# median profit: 7003 pips, median trade count: 446
# ....................
# episode: 520/1000
# median profit: 7019 pips, median trade count: 446
# ....................
# episode: 540/1000
# median profit: 7051 pips, median trade count: 443
# ....................
# episode: 560/1000
# median profit: 7003 pips, median trade count: 443
# ....................
# episode: 580/1000
# median profit: 7051 pips, median trade count: 441
# ....................
# episode: 600/1000
# median profit: 7074 pips, median trade count: 441
# ....................
# episode: 620/1000
# median profit: 7051 pips, median trade count: 438
# ....................
# episode: 640/1000
# median profit: 7084 pips, median trade count: 437
# ....................
# episode: 660/1000
# median profit: 7081 pips, median trade count: 436
# ....................
# episode: 680/1000
# median profit: 7019 pips, median trade count: 433
# ....................
# episode: 700/1000
# median profit: 7049 pips, median trade count: 436
# ....................
# episode: 720/1000
# median profit: 7002 pips, median trade count: 433
# ....................
# episode: 740/1000
# median profit: 6949 pips, median trade count: 432
# ....................
# episode: 760/1000
# median profit: 7019 pips, median trade count: 431
# ....................
# episode: 780/1000
# median profit: 7084 pips, median trade count: 431
# ....................
# episode: 800/1000
# median profit: 7160 pips, median trade count: 431
# ....................
# episode: 820/1000
# median profit: 7212 pips, median trade count: 430
# ....................
# episode: 840/1000
# median profit: 7231 pips, median trade count: 428
# ....................
# episode: 860/1000
# median profit: 7209 pips, median trade count: 425
# ....................
# episode: 880/1000
# median profit: 7231 pips, median trade count: 424
# ....................
# episode: 900/1000
# median profit: 7239 pips, median trade count: 419
# ....................
# episode: 920/1000
# median profit: 7282 pips, median trade count: 419
# ....................
# episode: 940/1000
# median profit: 7305 pips, median trade count: 418
# ....................
# episode: 960/1000
# median profit: 7314 pips, median trade count: 417
# ....................
# episode: 980/1000
# median profit: 7299 pips, median trade count: 415
# ....................
# episode: 1000/1000
# median profit: 7282 pips, median trade count: 414

# %%
train_results['profit_pips'] = train_results['account_balance'] / 0.0001
columns_to_plot = ['win_loss_ratio', 'profit_pips', 'trade_count']
fig, axes = plt.subplots(nrows=1,ncols=len(columns_to_plot), figsize=(16,6))
for i in range(len(columns_to_plot)):
    axes[i].title.set_text(columns_to_plot[i])
    train_results[columns_to_plot[i]].plot(ax=axes[i], subplots=True)
plt.show()

# %%
joblib.dump(agent, '{0}.pkl'.format(notebook_name))
# Out:
# ['12h-GBP_USD-high-spread.pkl']

# %% [markdown]
# ## Test

# %%
# Uncomment to load agent from file 
# agent = joblib.load('{0}.pkl'.format(notebook_name))

# %%
# remake the env with test data
env = SimpleTradingEnvironment(
    price_data=test_data,
    environment_columns=environment_columns,
    spread=0.0007
)
state_size = env.observation_space.shape
action_size = env.action_space.n
scaler = get_scaler(env)
test_results = pd.DataFrame()

# %%
for e in range(1000):
    state = env.reset()
    state = scaler.transform([state])
    for i in range(env.n_step):
        action = agent.act(state)
        next_state, reward, done = env.step(action)
        next_state = scaler.transform([next_state])
        state = next_state
        if done:
            test_results = test_results.append(env._stats(), ignore_index=True)
            break

# %%
test_results['account_balance_pips'] = test_results['account_balance'] / 0.0001
test_results['account_drawdown_max_pips'] = test_results['account_drawdown_max'] / 0.0001
print('Median profit: {0} pips'.format(test_results['account_balance_pips'].median()))
print('Median drawdown: {0} pips'.format(test_results['account_drawdown_max_pips'].median()))
# Out:
# Median profit: 4253.849999999871 pips
# Median drawdown: -1494.9000000000078 pips

# %%
# Historgram of account balance
plt.figure(figsize=(16,6))
test_results.hist(column='account_balance_pips', bins=60)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13b277d10>]],
#       dtype=object)

# %%
# Historgram of max drawdown
plt.figure(figsize=(16,6))
test_results.hist(column='account_drawdown_max_pips', bins=60)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13b276550>]],
#       dtype=object)

# %% [markdown]
# ## Analyse positions on test data

# %%
# remake the env with test data
env = SimpleTradingEnvironment(
    price_data=test_data.copy(),
    environment_columns=environment_columns,
    save_positions_on_df=True,
    spread=0.00015
)
state_size = env.observation_space.shape
action_size = env.action_space.n

# %%
state = env.reset()
state = scaler.transform([state])
for i in range(env.n_step):
    action = agent.act(state)
    next_state, reward, done = env.step(action)
    next_state = scaler.transform([next_state])
    state = next_state
    if done:
        break

# %%
env._stats()
# Out:
# {'trade_count': 155,
#  'win_loss_ratio': 0.632258064516129,
#  'account_balance': 0.17183499999999308,
#  'unrealised_pl': 0.00293499999999991,
#  'account_drawdown': 0.0,
#  'account_drawdown_max': -0.15301500000000035}

# %%
position_data = env.price_data.copy()

# %%
position_data['position'] = position_data['position'] - 1

# %%
trades = trade_functions.create_trades_from_positions(position_data.copy())

# %%
trade_functions.show_positions_on_price_plot(position_data.copy())
# Out:
# 157 positions to plot...

# %%
trade_functions.get_trade_statistics(trades.copy())
# Out:
# Profitable: 63.06%
# Ratio of long to short positions: 0.86
# Median profit: 0.0
# Total profit: 0.18647000000000036
# Median position length: 4.0
# Number of trades: 157

# %%
trades
# Out:
#              enter_date  enter_price           exit_date  exit_price  \
# 0   2015-07-01 00:00:00      1.56557 2015-07-01 12:00:00     1.56034
# 1   2015-07-01 12:00:00      1.56034 2015-08-25 00:00:00     1.57876
# 2   2015-08-25 00:00:00      1.57876 2015-08-26 00:00:00     1.55804
# 3   2015-08-26 00:00:00      1.55804 2015-10-20 00:00:00     1.54746
# 4   2015-10-20 12:00:00      1.54458 2015-12-24 00:00:00     1.49202
# ..                  ...          ...                 ...         ...
# 152 2020-03-12 00:00:00      1.27315 2020-03-12 12:00:00     1.25732
# 153 2020-03-12 12:00:00      1.25732 2020-03-15 12:00:00     1.23986
# 154 2020-03-16 00:00:00      1.23315 2020-03-17 00:00:00     1.21111
# 155 2020-03-17 12:00:00      1.21165 2020-03-27 00:00:00     1.22210
# 156 2020-03-27 00:00:00      1.22210 2020-05-14 00:00:00     1.21909
#
#      position_length  position   profit  profitable  account_balance
# 0                  1       NaN      NaN       False              NaN
# 1                 85       1.0  0.01842        True          0.01842
# 2                  2      -1.0  0.02072        True          0.03914
# 3                 86       1.0 -0.01058       False          0.02856
# 4                102       1.0 -0.05256       False         -0.02400
# ..               ...       ...      ...         ...              ...
# 152                1       1.0 -0.01583       False          0.13351
# 153                3      -1.0  0.01746        True          0.15097
# 154                2      -1.0  0.02204        True          0.17301
# 155               16       1.0  0.01045        True          0.18346
# 156               75      -1.0  0.00301        True          0.18647
#
# [157 rows x 9 columns]

# %%
# Plot account balance
trades['account_balance'].plot(figsize=(16,6))

# %% [markdown]
# ## Show distribution of maximum drawdown

# %%
max_drawdown_results = trade_functions.plot_max_drawdown_distribution(trades.copy())
plt.figure(figsize=(16,6))
plt.hist(max_drawdown_results, bins=100);
# Out:
# Median drawdown: -0.13846499999999962
